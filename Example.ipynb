# %%
# %matplotlib inline
import matplotlib.pyplot as plt

plt.plot([1, 2, 3, 4])
plt.ylabel('Numbers')
plt.show()

# %%
# %matplotlib widget
# %matplotlib inline

import matplotlib.pyplot as plt

plt.plot([1, 9, 3, 5, 2])
plt.ylabel('Number')
plt.show()
