# %% [markdown]
# ### Histogram Plot

# %%
import matplotlib.pyplot as plt 

data = [22, 25, 27, 30, 32, 33, 35, 36, 40, 45, 50]

plt.hist(data, bins=5, color='pink', edgecolor='black')

plt.title('Histogram')
plt.xlabel('Value Range')
plt.ylabel('Frequency')

plt.show()

# %% [markdown]
# ##### Adding Value Labels with plt.text()

# %%
import matplotlib.pyplot as plt

players = ["Sachin", "Sehwag", "Kohli"]
runs = [1590, 1260, 1859]

plt.bar(players, runs, color="#99eb95")

# Add labels on top of bars
for i in range(len(players)):
    plt.text(i, runs[i] + 30, str(runs[i]), ha='center')

plt.ylabel("Runs")
plt.title("Runs Scored by Players")
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

data = [54,65,45,34,54,23,21,12,
        89,65,67,32,36,76,90,5,
        65,32,44,89,65,34,21,34,
        34,67,98,23,59,80,5,4,11]
plt.hist(data, bins=5, edgecolor="black")
plt.xlabel("Marks")
plt.ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %% [markdown]
# ##### Example: Age Distribution of YouTube Viewers

# %%
import matplotlib.pyplot as plt
 
ages = [
    34, 28, 36, 45, 27, 27, 45, 37, 25, 35,
    25, 25, 32, 10, 12, 24, 19, 33, 20, 15,
    44, 27, 30, 15, 24, 31, 18, 33, 23, 27,
    23, 48, 29, 19, 38, 17, 32, 10, 16, 31,
    37, 31, 28, 26, 15, 22, 25, 40, 33, 12,
    33, 26, 23, 36, 40, 39, 21, 26, 33, 39,
    25, 28, 18, 18, 38, 43, 29, 40, 33, 23,
    33, 45, 29, 45, 3, 38, 30, 27, 30, 10,
    27, 33, 44, 24, 21, 24, 39, 33, 24, 35,
    30, 39, 22, 26, 26, 15, 32, 32, 30, 27
]

bins = [10, 20, 30, 40, 50, 60, 70]
plt.hist(ages, bins=bins, edgecolor="black")
plt.title("Age Distribution of YouTube Viewers")
plt.xlabel("Age Group")
plt.ylabel("Numbers of Viewers")
plt.grid(True, linestyle="--", alpha=0.5)
plt.show()

# %% [markdown]
# ##### Adding a Vertical Line: axvline

# %%
plt.hist(ages, bins=bins, edgecolor="black")
plt.axvline(15, color="red", linestyle="--", linewidth=1, label="Average") 
plt.title("Age Distribution of YouTube Viewers")
plt.xlabel("Age Group")
plt.ylabel("Numbers of Viewers")
plt.grid(True, linestyle="--", alpha=0.5)
plt.show()
